# %%
import yaml
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import sys
import os
import datetime
import re
from collections import defaultdict
import pickle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVC
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from joblib import dump, load
import statsmodels.api as sm
from tqdm import tqdm
from itertools import product

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# !git clone https://github.com/aavail/ai-workflow-capstone

# %%
params = yaml.safe_load(open('../params.yaml'))

TRAIN_PATH = params['path']['train']
TEST_PATH = params['path']['test']
MODEL_PATH = params['path']['model']

models_list = {'Ridge': Ridge(random_state=42),
               'Lasso': Lasso(random_state=42),
               'RandomForest': RandomForestRegressor(random_state=42),
               'GradientBoosting': GradientBoostingRegressor(random_state=42),
               'SVC': SVC(random_state=42)
}

COUNTRIES = params['countries']

# %%
def collect_data(path):
    
    if not os.path.isdir(path):
        raise(Exception('Directory does not exist'))
    
    columns = ['country', 'customer_id', 'invoice', 'price', 'stream_id', 'times_viewed', 'year', 'month', 'day']
    json_list = [i for i in os.listdir(path) if re.fullmatch(r'.+\.json$', i)]

    data = pd.DataFrame(columns=columns)

    if len(json_list) < 1:
        raise(Exception('No file to load'))
       
    
    for file_name in json_list:
        df = pd.read_json(os.path.join(path, file_name))
        df.columns = columns
        data = data.append(df)
    
    data['date'] = pd.to_datetime(data.year.astype('str')+'-'+data.month.astype('str')+'-'+data.day.astype('str'))
    data['country'] = data.country.str.lower()
           
    return data.sort_values(by='date').reset_index(drop=True)

# %%
data = collect_data(TRAIN_PATH)
data
# Out:
#                country  customer_id invoice  price stream_id times_viewed  \
# 0       united kingdom      16393.0  489536   0.85     22356            3
# 1       united kingdom      13097.0  489574   2.95     21548            1
# 2       united kingdom      13085.0  489434   6.75    79323P           12
# 3       united kingdom      13085.0  489434   6.75    79323W           12
# 4       united kingdom      13085.0  489434   2.10     22041           21
# ...                ...          ...     ...    ...       ...          ...
# 815006  united kingdom      13384.0  562132   2.08     23199            2
# 815007  united kingdom      13384.0  562132   0.83     23294           12
# 815008  united kingdom      13384.0  562132   1.25     23296           12
# 815009  united kingdom      15039.0  562158   1.65     20726           10
# 815010  united kingdom      13851.0  562218   4.95     23126            4
#
#         year month day       date
# 0       2017    11  28 2017-11-28
# 1       2017    11  28 2017-11-28
# 2       2017    11  28 2017-11-28
# 3       2017    11  28 2017-11-28
# 4       2017    11  28 2017-11-28
# ...      ...   ...  ..        ...
# 815006  2019     7  31 2019-07-31
# 815007  2019     7  31 2019-07-31
# 815008  2019     7  31 2019-07-31
# 815009  2019     7  31 2019-07-31
# 815010  2019     7  31 2019-07-31
#
# [815011 rows x 10 columns]

# %%
def convert_data(original_data, country):
    
    df = original_data.copy()

    start_date = df.date.min()
    end_date = df.date.max()
    dates_range = pd.date_range(start_date, end_date)
    
    if country!='all':
        if country not in df.country.unique():
            raise Exception('Country not found')
        df = df[df.country==country]
    
    df['invoice'] = df.invoice.str.extract(r'([0-9]+)')
    
    
    df_to_join = pd.DataFrame({'date': dates_range})
    df_to_join['month'] = df_to_join.date.dt.strftime('%Y-%m')

    
    
    df = df.groupby('date').agg({'country': len,
                                 'invoice': lambda x: len(np.unique(x)),
                                 'stream_id': lambda x: len(np.unique(x)),
                                 'times_viewed': np.sum,
                                 'price': np.sum}).reset_index()
    
    df.rename(columns={'invoice': 'unique_invoices',
                       'times_viewed': 'total_views',
                       'price': 'revenue',
                       'country': 'purchases',
                       'stream_id': 'total_streams'}, inplace=True)
  
    
    
    df = pd.merge(df_to_join, df, how='left', on='date').fillna(0)
   
    return df

# %%
data_1 = convert_data(data, country='all')
data_1
# Out:
#           date    month  purchases  unique_invoices  total_streams  \
# 0   2017-11-28  2017-11     3223.0            166.0         1345.0
# 1   2017-11-29  2017-11     3277.0            133.0         1397.0
# 2   2017-11-30  2017-11     3002.0            150.0         1335.0
# 3   2017-12-01  2017-12     2559.0            107.0         1256.0
# 4   2017-12-02  2017-12      402.0             32.0          287.0
# ..         ...      ...        ...              ...            ...
# 606 2019-07-27  2019-07        0.0              0.0            0.0
# 607 2019-07-28  2019-07     1271.0             43.0          789.0
# 608 2019-07-29  2019-07     1200.0             51.0          770.0
# 609 2019-07-30  2019-07     1369.0             61.0          862.0
# 610 2019-07-31  2019-07     1560.0             84.0          871.0
#
#      total_views   revenue
# 0        15047.0  14450.54
# 1        14159.0  13411.96
# 2        15766.0  13290.25
# 3        12524.0   9687.28
# 4         3313.0   1443.26
# ..           ...       ...
# 606          0.0      0.00
# 607       7004.0   3150.26
# 608       7025.0   4374.54
# 609       8492.0  16374.76
# 610       9473.0   4964.93
#
# [611 rows x 7 columns]

# %%
sm.tsa.adfuller(data_1.revenue)
# Out:
# (-7.116464502409079,
#  3.819546367093723e-10,
#  6,
#  604,
#  {'1%': -3.4412230283528937,
#   '5%': -2.8663370524631344,
#   '10%': -2.5693247196394893},
#  12601.755438455328)

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6))
sm.graphics.tsa.plot_acf(data_1.revenue.values, lags=60, ax=ax)

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6))
sm.graphics.tsa.plot_pacf(data_1.revenue.values, lags=160, ax=ax)

# %%
data_1[['date', 'revenue']].set_index('date')
# Out:
#              revenue
# date
# 2017-11-28  14450.54
# 2017-11-29  13411.96
# 2017-11-30  13290.25
# 2017-12-01   9687.28
# 2017-12-02   1443.26
# ...              ...
# 2019-07-27      0.00
# 2019-07-28   3150.26
# 2019-07-29   4374.54
# 2019-07-30  16374.76
# 2019-07-31   4964.93
#
# [611 rows x 1 columns]

# %%
X = data_1[['date', 'revenue']].set_index('date')[:'2019-04-30']
y = data_1[['date', 'revenue']].set_index('date')['2019-05-01':]

model = sm.tsa.statespace.SARIMAX(X, order=(3,0,1), seasonal_order=(7,0,7,7)).fit(disp=-1)

# %%
preds = model.predict('2019-05-01', '2019-07-31')

plt.figure(figsize=(18,6))
plt.plot(preds)
plt.plot(y)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                revenue   No. Observations:                  519
# Model:                     ARMA(1, 1)   Log Likelihood               -5202.376
# Method:                       css-mle   S.D. of innovations           5457.173
# Date:                Tue, 06 Sep 2022   AIC                          10412.752
# Time:                        07:08:50   BIC                          10429.759
# Sample:                    11-28-2017   HQIC                         10419.415
#                          - 04-30-2019
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          6139.3454    590.800     10.392      0.000    4981.398    7297.293
# ar.L1.revenue     0.9271      0.034     27.056      0.000       0.860       0.994
# ma.L1.revenue    -0.8176      0.052    -15.803      0.000      -0.919      -0.716
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0786           +0.0000j            1.0786            0.0000
# MA.1            1.2230           +0.0000j            1.2230            0.0000
# -----------------------------------------------------------------------------
# """

# %%
qs = range(8)
d = 0
ps = range(8)

ss = 7
QS = range(5)
PS = range(5)
D = 0

best_model = None
best_error = 1e10
best_params = None

for pars in tqdm(product(ps, qs, PS, QS)):
    p, q, P, Q = pars
    try:
        model = sm.tsa.statespace.SARIMAX(X, order=(p,d,q), seasonal_order=(P,D,Q,s)).fit(disp=-1)
    except:
        continue
    
    preds = model.predict('2019-05-01', '2019-07-31')
    model_error = mean_squared_error(y.revenue.values, preds.values)**0.5
    print(model_error)
    
    if model_error < best_error:
        best_error = model_error
        best_model = model
        best_params = (p, d, q, P, D, Q, ss)
# Out:
# 2it [00:00, 19.51it/s]
# 7829.526280731441
# 7626.246611669774
# 7611.558096224631
# 4it [00:00,  3.70it/s]
# 7530.053023619226
# 5it [00:01,  2.68it/s]
# 7552.822144705225
# 7236.564574855475
# 7it [00:01,  3.71it/s]
# 4531.54557557791
# 8it [00:02,  2.07it/s]
# 4281.790806747101
# 9it [00:04,  1.42it/s]
# 4281.872642479692
# 10it [00:07,  1.25s/it]
# 4273.102190196088
# 6913.295578619287
# 12it [00:07,  1.21it/s]
# 4273.830317853141
# 13it [00:08,  1.12it/s]
# 4291.2186787436
# 14it [00:11,  1.25s/it]
# 4249.824724186055
# 16it [00:15,  1.60s/it]
# 4259.264312670991
# 6430.852658430202
# 17it [00:18,  1.79s/it]
# 4293.92900504602
# 18it [00:19,  1.79s/it]
# 4256.420711738594
# 19it [00:22,  2.04s/it]
# 4311.545242095192
# 20it [00:26,  2.60s/it]
# 4349.147424760149
# 21it [00:26,  1.91s/it]
# 5967.074987901396
# 22it [00:29,  2.10s/it]
# 4290.122898620443
# 23it [00:33,  2.61s/it]
# 4267.344617257725
# 24it [00:36,  2.80s/it]
# 4346.548459132099
# 25it [00:42,  3.78s/it]
# 4357.729179873068
# 7869.967324353647
# 28it [00:42,  1.62s/it]
# 7645.378597911297
# 7599.05667927455
# 29it [00:43,  1.28s/it]
# 7506.711811653824
# 30it [00:43,  1.13s/it]
# 7509.138317928078
# 7271.401850102619
# 32it [00:44,  1.35it/s]
# 4367.788474305355
# 33it [00:45,  1.27it/s]
# 4313.636759267667
# 34it [00:47,  1.17s/it]
# 4292.058456330068
# 35it [00:52,  2.05s/it]
# 4297.657660064061
# 6934.296176610168
# 37it [00:53,  1.39s/it]
# 4308.514200759144
# 38it [00:54,  1.48s/it]
# 4366.904664317665
# 39it [00:59,  2.26s/it]
# 4307.34271786563
# 41it [01:09,  3.06s/it]
# 4302.418940417025
# 6454.271408433361
# 42it [01:12,  3.05s/it]
# 4319.026876623426
# 43it [01:17,  3.83s/it]
# 4373.991800787356


# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# =================================================================================================
# Dep. Variable:                                   revenue   No. Observations:                  519
# Model:             SARIMAX(1, 0, 1)x(3, 0, [1, 2, 3], 7)   Log Likelihood               -5540.049
# Date:                                   Tue, 06 Sep 2022   AIC                          11098.097
# Time:                                           04:17:43   BIC                          11136.364
# Sample:                                       11-28-2017   HQIC                         11113.089
#                                             - 04-30-2019
# Covariance Type:                                     opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8879      0.085     10.488      0.000       0.722       1.054
# ma.L1         -0.7583      0.115     -6.574      0.000      -0.984      -0.532
# ar.S.L7        0.1759      0.170      1.033      0.301      -0.158       0.509
# ar.S.L14      -0.1128      0.216     -0.523      0.601      -0.536       0.310
# ar.S.L21       0.9348      0.205      4.562      0.000       0.533       1.336
# ma.S.L7       -0.1957      0.189     -1.036      0.300      -0.566       0.175
# ma.S.L14       0.1512      0.237      0.638      0.524      -0.314       0.616
# ma.S.L21      -0.9129      0.214     -4.271      0.000      -1.332      -0.494
# sigma2      1.295e+08   6.97e-09   1.86e+16      0.000     1.3e+08     1.3e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):            228018.82
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.05   Skew:                             7.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                       104.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.3e+31. Standard errors may be unstable.
# """

# %%
preds = best_model.predict('2019-05-01', '2019-07-31')

# %%
plt.figure(figsize=(18,6))
plt.plot(preds)
plt.plot(y)

# %%
plt.figure(figsize=(18, 6))
data_1.revenue.plot()
# Out:
# <AxesSubplot:>

# %%
crit_value = data_1.revenue.mean() + 4*(np.percentile(data_1.revenue, 75) - np.percentile(data_1.revenue, 25))
data_1.loc[data_1.revenue>crit_value, 'revenue'] = crit_value

# %%
data_1.loc[data_1.revenue<0, 'revenue'] = 0

# %%
y
# Out:
#              revenue
# date
# 2019-05-01   3593.41
# 2019-05-02   6246.54
# 2019-05-03   7276.01
# 2019-05-04      0.00
# 2019-05-05   4316.80
# ...              ...
# 2019-07-27      0.00
# 2019-07-28   3150.26
# 2019-07-29   4374.54
# 2019-07-30  16374.76
# 2019-07-31   4964.93
#
# [92 rows x 1 columns]

# %%
preds
# Out:
# 2019-05-01     6933.597596
# 2019-05-02     8464.463931
# 2019-05-03     7417.991759
# 2019-05-04      529.416181
# 2019-05-05     3831.009969
#                   ...
# 2019-07-27       61.680073
# 2019-07-28     3382.023538
# 2019-07-29     7039.718206
# 2019-07-30    10239.128319
# 2019-07-31     5995.763903
# Freq: D, Name: predicted_mean, Length: 92, dtype: float64

# %%
(mean_squared_error(y.revenue.values, preds.values))**0.5
# Out:
# 5499.947011327963

# %%
plt.figure(figsize=(18,6))
data_1.plot(kind='line', x='date', y='revenue', figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
model =

# %%
for i in tqdm(product([1,2,3], [3,4])):
    print(i)
# Out:
# 6it [00:00, 10917.93it/s]
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 3)
# (3, 4)

# %%
i = 60

X = data_1.revenue.values[:-i]
y = data_1.revenue.values[-i:]
X_new = X.copy().tolist()

for _ in range(i):
    pred = np.mean(X_new[-5:])
    print(pred)
    X_new.append(pred)
# Out:
# 4247.01
# 4080.3360000000002
# 3730.1632000000004
# 3063.1838400000006
# 3024.138608
# 3628.966329600001
# 3505.3575955200004
#         3631.94 ,     0.   ,  3150.26 ,  4374.54 , 16374.76 ,  4964.93 ])

# %%
X_new[-60:]
# Out:
# [5570.872666666667,
#  5514.034755555555,
#  5697.835914074075,
#  5743.87044454321,
#  5643.816792694651,
#  5315.792352451139,
#  5293.998764199509,
#  5185.5410563394935,
#  5193.14709155081,
#  5366.251994602502,
#  5469.215061089253,
#  4954.934896458896,
#  4782.876059674193,
#  4764.969928329999,
#  4665.105925940998,
#  4688.268123472365,
#  4844.543727588111,
#  4852.804518507714,
#  4594.267335791304,
#  4504.371580317683,
#  4502.727632994938,
#  4510.154220761437,
#  4487.01802812015,
#  4636.585295724156,
#  4733.9351389149615,
#  4891.732976878793,
#  4885.444742774753,
#  4853.9195675339115,
#  4780.2148864517085,
#  4830.941716000099,
#  4991.973106533435,
#  4972.6764545289925,
#  4954.631177828108,
#  4929.857686619909,
#  4902.723928022465,
#  4878.020832533392,
#  4863.428448536134,
#  4849.076104680689,
#  4837.860606292062,
#  4826.017723450103,
#  4808.009914411691,
#  4785.969742855772,
#  4780.337571069002,
#  4780.252954782161,
#  4780.762388997234,
#  4784.617604432441,
#  4787.829253797779,
#  4785.938771338099,
#  4783.709913099112,
#  4790.024665676038,
#  4799.546435187983,
#  4809.4403952610855,
#  4819.416601077741,
#  4830.49655350966,
#  4836.960262102511,
#  4840.39443287543,
#  4838.683148075316,
#  4837.124428252001,
#  4836.564590275938,
#  4838.442913736744]

# %%
V = X[-61]
beta = 0.1
pred = []

for x in X[-60:]:
    V = x*beta + (1-beta)*V
    pred.append(V)

# %%
plt.plot(pred)
plt.plot(X[-60:])

# %%
X[-60:]
# Out:
# array([ 3770.26 ,  4707.59 ,  9002.98 ,     0.   ,  3110.41 ,  3611.43 ,
#         3700.69 ,  3022.28 ,  5481.55 ,  8714.421,     0.   ,  2774.57 ,
#        12345.27 ,  7149.88 ,  3238.39 ,  9542.42 ,     0.   ,     0.   ,
#            0.   ,     0.   ,  8523.9  ,  4271.07 ,  4706.13 ,     0.   ,
#            0.   ,  1298.41 ,     0.   , 28575.59 ,  3593.41 ,  6246.54 ,
#         7276.01 ,     0.   ,  4316.8  ,  8745.48 , 15484.55 ,  5969.6  ,
#         8547.73 ,  4957.36 ,     0.   ,  2277.36 , 20897.62 , 10116.7  ,
#         5320.06 ,  7760.89 ,  3970.24 ,     0.   ,  4596.72 , 12608.92 ,
#         7291.14 ,  4553.69 ,  4279.93 ,  5204.24 ,     0.   ,  1716.09 ,
#            0.   ,  5080.38 ,  5831.2  ,  7065.06 ,  3258.41 ,     0.   ])

# %%
def get_data(path, country=None, renew=False):
    
    data_csv_path = os.path.join(path, 'convert_data')
    
    if not os.path.isdir(data_csv_path):
        os.mkdir(data_csv_path)
           
    countries_to_csv = set(COUNTRIES) if renew \
                    else set(COUNTRIES).difference([i.split('.')[0] for i in os.listdir(data_csv_path)]) 
    
    if len(countries_to_csv) > 0:
        print('...Collect json files')
        df = collect_data(path)
        print('...Create csv files')
        for c in countries_to_csv:
            data_country = convert_data(df, c)
            data_country.to_csv(os.path.join(data_csv_path, c)+'.csv', index=False)
            print(f'......csv file for {c} created successfuly')
        print('...all csv files created successfuly')
    
    if country:
        return {country: pd.read_csv(os.path.join(data_csv_path, country.lower())+'.csv')}
        
    return {i.split('.')[0]: pd.read_csv(os.path.join(data_csv_path, i)) for i in os.listdir(data_csv_path)}

# %%
get_data(TRAIN_PATH, 'all')
# Out:
# {'all':            date    month  purchases  unique_invoices  total_streams  \
#  0    2017-11-28  2017-11     3223.0            166.0         1345.0
#  1    2017-11-29  2017-11     3277.0            133.0         1397.0
#  2    2017-11-30  2017-11     3002.0            150.0         1335.0
#  3    2017-12-01  2017-12     2559.0            107.0         1256.0
#  4    2017-12-02  2017-12      402.0             32.0          287.0
#  ..          ...      ...        ...              ...            ...
#  606  2019-07-27  2019-07        0.0              0.0            0.0
#  607  2019-07-28  2019-07     1271.0             43.0          789.0
#  608  2019-07-29  2019-07     1200.0             51.0          770.0
#  609  2019-07-30  2019-07     1369.0             61.0          862.0
#  610  2019-07-31  2019-07     1560.0             84.0          871.0
#
#       total_views   revenue
#  0        15047.0  14450.54
#  1        14159.0  13411.96
#  2        15766.0  13290.25
#  3        12524.0   9687.28
#  4         3313.0   1443.26
#  ..           ...       ...
#  606          0.0      0.00
#  607       7004.0   3150.26
#  608       7025.0   4374.54
#  609       8492.0  16374.76
#  610       9473.0   4964.93
#
#  [611 rows x 7 columns]}

# %%
def engineer_features(data, mode='train'):

    def get_value(start_date, end_date, feature='revenue', func=np.sum):
        mask = np.in1d(dates, np.arange(start_date, end_date, dtype='datetime64[D]'))
        return func(data.loc[mask, feature])
    
    dates = data.date.values.copy().astype('datetime64[D]')   
    periods = [7, 14, 21, 28, 35, 42, 49, 56, 63, 70]
    columns = defaultdict(list)
    target = []
    
    for idx, date in enumerate(dates[1:-30]):
        cur = np.datetime64(date)

        for per in periods:
            columns[f'{per}_revenue'].append(get_value(cur-np.timedelta64(per, 'D'), cur))
          
        target.append(get_value(cur, cur+np.timedelta64(30, 'D')))
        columns['year_ago'].append(get_value(cur-np.timedelta64(365, 'D'), cur-np.timedelta64(335, 'D')))
        columns['mean_invoice'].append(get_value(cur-np.timedelta64(30, 'D'), cur, 'unique_invoices', np.mean))
        columns['mean_views'].append(get_value(cur-np.timedelta64(30, 'D'), cur, 'total_views', np.mean))
            
    return pd.DataFrame(columns), target, dates[1:-30]

# %%
_, X, dates = engineer_features(data_1)

# %%
XX = pd.DataFrame({'X': X}, index=dates)

X = XX[:'2019-04-30']
y = XX['2019-05-01':]

# %%
plt.plot(X)

# %%
sm.tsa.adfuller(X)
# Out:
# (-3.6740694876780746,
#  0.004493031900227621,
#  14,
#  503,
#  {'1%': -3.4434175660489905,
#   '5%': -2.8673031724657454,
#   '10%': -2.5698395516760275},
#  11008.232060987457)

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6))
sm.graphics.tsa.plot_acf(X.diff(1).dropna(), lags=120, ax=ax)

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6))
sm.graphics.tsa.plot_pacf(X.diff(1).dropna(), lags=120, ax=ax)

# %%
model = sm.tsa.statespace.SARIMAX(X, order=(2,1,2), seasonal_order=(3,0,1,30)).fit(disp=-1)
# model = sm.tsa.ARIMA(X, order=(7,1,7)).fit(full_output=False, disp=0)

# %%
preds = model.predict('2019-05-01', '2019-07-31')
plt.plot(y)
plt.plot(preds)

# %%
plt.figure(figsize=(18,6))
plt.plot(X.diff(1).dropna())

# %%
def get_last_model_version(path):
    return max([int(re.findall(r'\d+', i.split('_')[5])[0]) for i in os.listdir(path)])

# %%
def set_model_to_test_version(path):
    
    def rename_model(model_name, replace_sample):
        if replace_sample == ('SL__', 'TEST__'):
            print(f'...Set {candidate} as test model')
        old_model_name = os.path.join(path, model_name)
        new_model_name = os.path.join(path, model_name.replace(*replace_sample))
        os.rename(old_model_name, new_model_name)

    
    full_models_list = os.listdir(path)
    sl_models_list = [i for i in full_models_list if i.startswith('SL__')]

    sl_models_errors = [int(re.findall(r'\d+', i.split('_')[6])[0]) for i in sl_models_list]
    candidate = sl_models_list[np.argmin(sl_models_errors)]
    
    
    if len([i for i in full_models_list if i.startswith('TEST__')]) == 0:
        rename_model(candidate, ('SL__', 'TEST__'))
    else:
        current_test_model = [i for i in full_models_list if i.startswith('TEST__')][0]
        current_test_model_error = int(re.findall(r'\d+', current_test_model.split('_')[6])[0])
        candidate_error = np.min(sl_models_errors)    
        
        if candidate_error < current_test_model_error:
            rename_model(candidate, ('SL__', 'TEST__'))
            rename_model(current_test_model, ('TEST__', 'SL__'))    
        else: 
            print('...The quality of the new models is worse than the current test model')

# %%
def save_model(model, start_name, path, error):
       
    if not os.path.isdir(path):
        os.mkdir(path)
        model_version = 0
    else:
        if len(os.listdir(path)) == 0:
            model_version = 0
        else:
            model_version = get_last_model_version(path)
    
    date_tag = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
    
    model_name = f'SL__{start_name}_{date_tag}_v{model_version+1}_err{int(error)}.joblib'
    
    dump(model, os.path.join(path, model_name))

# %%
def load_model(country, version=None):
    
    path = os.path.join(MODEL_PATH, country.lower())
    
    if country.lower() not in COUNTRIES:
        print(f'...For this country no models. You can load models for countries in this list:')
        print('......', ', '.join(COUNTRIES))
        return None
    
    if not os.path.isdir(path):
        os.mkdir(path)
    
    test_list = [i for i in os.listdir(path) if i.startswith('TEST__')]   
    
    if version:
        models_vers = [re.findall(r'\d', i.split('_')[5])[0] for i in os.listdir(path)]
        if str(version) not in models_vers:
            print(f'...Model with version {version} is not exist')
            return None
        model_name = os.listdir(path)[models_vers.index(str(version))]

    else:
        if len(test_list) == 0:
            fit_models(country)
        test_list = [i for i in os.listdir(path) if i.startswith('TEST__')]
        model_name = test_list[0]
        
    model = load(os.path.join(path, model_name))
    return model

# %%
def fit_models_(data, path, test=False):
    
    X, y = engineer_features(data)
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)
    
    
    for model_name in params['models']:
        print(f'......Train {model_name} model')
        model = models_list[model_name]
        
        pipline = Pipeline(steps=[
            ('scaler', StandardScaler()),
            (model_name, model)
        ])
        
        param_grid = params['models'][model_name]
        
        gcv = GridSearchCV(estimator=pipline, param_grid=param_grid)
        gcv.fit(X_train, y_train)
        best_estimator = gcv.best_estimator_
        
        preds = best_estimator.predict(X_val)
        error = np.sqrt(mean_squared_error(preds, y_val))
        
        print(f'.........RMSE for {model_name} on validation = {error}')
        
        save_model(best_estimator, model_name, path, error)
        
    set_model_to_test_version(path)

# %%
# Функция, которая обучвет модель и слхраняет ее в папке со страной

def fit_models(country=None, renew_data=False):
    
    country = country.lower() if country else country
    dfs = get_data(TRAIN_PATH, country, renew_data)
    
    for country, df in dfs.items():
        print(f'...Train models for country: {country}')
        path = os.path.join(MODEL_PATH, country)
        fit_models_(df, path)
        print(f'...Models trained successfuly\n')

# %%
fit_models('all')
# Out:
# ...Train models for country: all
# ......Train RandomForest model
# .........RMSE for RandomForest on validation = 32332.901997502468
# ......Train Lasso model
# .........RMSE for Lasso on validation = 76169.16598718807
# ......Train GradientBoosting model
# .........RMSE for GradientBoosting on validation = 30179.647377567177
# ...Set SL__GradientBoosting_20220830_210013_v5_err30179.joblib as test model
# ...Models trained successfuly

# %%
def predict(country, day, month, year):
    pass
# Out:
# 11115167435.0

# %%
GradientBoostingRegressor()

# %%
d = get_data(TRAIN_PATH, country='all')['all']
d[d.revenue<0]
# Out:
#            date    month  purchases  unique_invoices  total_streams  \
# 149  2018-04-26  2018-04     2058.0            106.0         1046.0
# 230  2018-07-16  2018-07     1448.0             68.0          786.0
# 323  2018-10-17  2018-10     2491.0            122.0         1092.0
#
#      total_views    revenue
# 149      11371.0 -44990.049
# 230       8907.0 -38702.940
# 323      13319.0 -29374.970

# %%
d = convert_data(collect_data(TRAIN_PATH), 'all')

# %%
d.head()
# Out:
#         date    month  purchases  unique_invoices  total_streams  total_views  \
# 0 2017-11-28  2017-11     3223.0            166.0         1345.0      15047.0
# 1 2017-11-29  2017-11     3277.0            133.0         1397.0      14159.0
# 2 2017-11-30  2017-11     3002.0            150.0         1335.0      15766.0
# 3 2017-12-01  2017-12     2559.0            107.0         1256.0      12524.0
# 4 2017-12-02  2017-12      402.0             32.0          287.0       3313.0
#
#     revenue
# 0  14450.54
# 1  13411.96
# 2  13290.25
# 3   9687.28
# 4   1443.26

# %%
d = collect_data(TRAIN_PATH)

# %%
d.head()
# Out:
#           country  customer_id invoice  price stream_id times_viewed  year  \
# 0  united kingdom      16620.0  489598   2.10     22280            6  2017
# 1  united kingdom      13085.0  489434   6.75    79323P           12  2017
# 2  united kingdom      13085.0  489434   6.75    79323W           12  2017
# 3  united kingdom      13085.0  489434   2.10     22041           21  2017
# 4  united kingdom      13085.0  489434   1.25     21232            5  2017
#
#   month day       date
# 0    11  28 2017-11-28
# 1    11  28 2017-11-28
# 2    11  28 2017-11-28
# 3    11  28 2017-11-28
# 4    11  28 2017-11-28

# %%
d[d.price>10000]
# Out:
#                country  customer_id  invoice     price     stream_id  \
# 134998  united kingdom          NaN   502265  10953.50             M
# 135013  united kingdom      12918.0  C502262  10953.50             M
# 135014  united kingdom      12918.0   502263  10953.50             M
# 135015  united kingdom      12918.0  C502264  10953.50             M
# 241826  united kingdom      17399.0  C512770  25111.09             M
# 241829  united kingdom          NaN   512771  25111.09             M
# 320592  united kingdom          NaN  C520667  18910.69  BANK CHARGES
# 342048  united kingdom      14063.0  C522793  10468.80             M
# 342147  united kingdom          NaN   522796  10468.80             M
# 358636  united kingdom      14063.0   524159  10468.80             M
# 358666  united kingdom          NaN  C524161  10468.80             M
# 374115  united kingdom          NaN   525399  10468.80             M
# 374116  united kingdom      14063.0  C525398  10468.80             M
# 531974  united kingdom          NaN  C537630  13541.33     AMAZONFEE
# 531982  united kingdom          NaN   537632  13541.33     AMAZONFEE
# 533195  united kingdom          NaN  C537644  13474.79     AMAZONFEE
# 533343  united kingdom          NaN  C537651  13541.33     AMAZONFEE
# 534847  united kingdom          NaN   537632  13541.33     AMAZONFEE
# 534848  united kingdom          NaN  C537630  13541.33     AMAZONFEE
# 536088  united kingdom          NaN  C537644  13474.79     AMAZONFEE
# 536210  united kingdom          NaN  C537651  13541.33     AMAZONFEE
# 569149  united kingdom          NaN  C540118  16453.71     AMAZONFEE
# 569199  united kingdom          NaN  C540117  16888.02     AMAZONFEE
# 748140  united kingdom      15098.0  C556445  38970.00             M
#
#        times_viewed  year month day       date
# 134998            1  2018     3  20 2018-03-20
# 135013            2  2018     3  20 2018-03-20
# 135014            1  2018     3  20 2018-03-20
# 135015            1  2018     3  20 2018-03-20
# 241826            2  2018     6  14 2018-06-14
# 241829            1  2018     6  14 2018-06-14
# 320592            2  2018     8  24 2018-08-24
# 342048            1  2018     9  13 2018-09-13
# 342147            1  2018     9  13 2018-09-13
# 358636            1  2018     9  24 2018-09-24
# 358666            2  2018     9  24 2018-09-24
# 374115            1  2018    10   2 2018-10-02
# 374116            0  2018    10   2 2018-10-02
# 531974            3  2018    12   4 2018-12-04
# 531982            1  2018    12   4 2018-12-04
# 533195            0  2018    12   4 2018-12-04
# 533343            3  2018    12   4 2018-12-04
# 534847            1  2018    12   4 2018-12-04
# 534848            3  2018    12   4 2018-12-04
# 536088            3  2018    12   4 2018-12-04
# 536210            2  2018    12   4 2018-12-04
# 569149            2  2019     1   2 2019-01-02
# 569199            0  2019     1   2 2019-01-02
# 748140            1  2019     6   7 2019-06-07

# %%
d.describe()
# Out:
#          customer_id          price
# count  625249.000000  815011.000000
# mean    15333.415068       4.802631
# std      1698.360788     135.058707
# min     12346.000000  -53594.360000
# 25%     13956.000000       1.250000
# 50%     15279.000000       2.100000
# 75%     16813.000000       4.210000
# max     18287.000000   38970.000000

# %%
plt.plot(d.price)

# %%
d = get_data(TEST_PATH, 'all')

# %%
d['all'][d['all'].revenue<0]
# Out:
#          date    month  purchases  unique_invoices  total_streams  \
# 8  2019-08-09  2019-08     1122.0             61.0          717.0
#
#    total_views  revenue
# 8       6696.0 -6946.44

# %%
d = get_data(TRAIN_PATH, 'all')['all']
d.revenue.plot()
# Out:
# <AxesSubplot:>
